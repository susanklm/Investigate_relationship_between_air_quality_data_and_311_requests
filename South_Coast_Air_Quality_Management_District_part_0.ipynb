# %% [markdown]
# <h1><center>South Coast Air Quality Management District Sensors</center></h1>

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import FuncFormatter
import pandas as pd
import numpy as np
import seaborn as sns
from pandas.plotting import scatter_matrix
# %matplotlib inline
from branca.element import Figure
from pylab import rcParams

import folium
from folium.features import DivIcon
import geopandas as gpd
pd.set_option("display.max_columns", None)

import requests

# %% [markdown]
# In this notebook, we are trying to get the information of the sensors from South Coast Air Quality Management District, in particular its' exact locations within the Los Angeles Neighborhood Councils. The sensors' data were taken from [EPA's Air Quality System (AQS)]( https://aqs.epa.gov/aqsweb/documents/data_api.html#sample).

# %% [markdown]
# <h2>Getting Data Through Monitoring Station API</h2>

# %%
USER_ID = "susankol@alumni.usc.edu"
USER_KEY = "silvercat24"

# %%
# Find the State Code
url_state = "https://aqs.epa.gov/data/api/list/states?email={}&key={}".format(USER_ID, USER_KEY)

results = requests.get(url_state).json()
#results
for i in range(len(results["Data"])): 
    if "California" in results["Data"][i]['value_represented']:
        print(results["Data"][i])
# Out:
# {'code': '06', 'value_represented': 'California'}

# %%
# Find the County Code
url_county = "https://aqs.epa.gov/data/api/list/countiesByState?email={}&key={}&state=06".format(USER_ID, USER_KEY)

results = requests.get(url_county).json()
results
#for i in range(len(results["Data"])): 
#    if "Simi Valley" in results["Data"][i]['value_represented']:
#        print(results["Data"][i])
#   if "Los Angeles" in results["Data"][i]['value_represented']:
#        print(results["Data"][i])
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2022-10-12T19:14:12-04:00',
#    'url': 'https://aqs.epa.gov/data/api/list/countiesByState?email=susankol@alumni.usc.edu&key=silvercat24&state=06',
#    'rows': 58}],
#  'Data': [{'code': '001', 'value_represented': 'Alameda'},
#   {'code': '003', 'value_represented': 'Alpine'},
#   {'code': '005', 'value_represented': 'Amador'},
#   {'code': '007', 'value_represented': 'Butte'},
#   {'code': '009', 'value_represented': 'Calaveras'},
#   {'code': '011', 'value_represented': 'Colusa'},
#   {'code': '013', 'value_represented': 'Contra Costa'},
#   {'code': '015', 'value_represented': 'Del Norte'},
#   {'code': '017', 'value_represented': 'El Dorado'},
#   {'code': '019', 'value_represented': 'Fresno'},
#   {'code': '021', 'value_represented': 'Glenn'},
#   {'code': '023', 'value_represented': 'Humboldt'},
#   {'code': '025', 'value_represented': 'Imperial'},
#   {'code': '027', 'value_represented': 'Inyo'},
#   {'code': '029', 'value_represented': 'Kern'},
#   {'code': '031', 'value_represented': 'Kings'},
#   {'code': '033', 'value_represented': 'Lake'},
#   {'code': '035', 'value_represented': 'Lassen'},
#   {'code': '037', 'value_represented': 'Los Angeles'},
#   {'code': '039', 'value_represented': 'Madera'},
#   {'code': '041', 'value_represented': 'Marin'},
#   {'code': '043', 'value_represented': 'Mariposa'},
#   {'code': '045', 'value_represented': 'Mendocino'},
#   {'code': '047', 'value_represented': 'Merced'},
#   {'code': '049', 'value_represented': 'Modoc'},
#   {'code': '051', 'value_represented': 'Mono'},
#   {'code': '053', 'value_represented': 'Monterey'},
#   {'code': '055', 'value_represented': 'Napa'},
#   {'code': '057', 'value_represented': 'Nevada'},
#   {'code': '059', 'value_represented': 'Orange'},
#   {'code': '061', 'value_represented': 'Placer'},
#   {'code': '063', 'value_represented': 'Plumas'},
#   {'code': '065', 'value_represented': 'Riverside'},
#   {'code': '067', 'value_represented': 'Sacramento'},
#   {'code': '069', 'value_represented': 'San Benito'},
#   {'code': '071', 'value_represented': 'San Bernardino'},
#   {'code': '073', 'value_represented': 'San Diego'},
#   {'code': '075', 'value_represented': 'San Francisco'},
#   {'code': '077', 'value_represented': 'San Joaquin'},
#   {'code': '079', 'value_represented': 'San Luis Obispo'},
#   {'code': '081', 'value_represented': 'San Mateo'},
#   {'code': '083', 'value_represented': 'Santa Barbara'},
#   {'code': '085', 'value_represented': 'Santa Clara'},
#   {'code': '087', 'value_represented': 'Santa Cruz'},
#   {'code': '089', 'value_represented': 'Shasta'},
#   {'code': '091', 'value_represented': 'Sierra'},
#   {'code': '093', 'value_represented': 'Siskiyou'},
#   {'code': '095', 'value_represented': 'Solano'},
#   {'code': '097', 'value_represented': 'Sonoma'},
#   {'code': '099', 'value_represented': 'Stanislaus'},
#   {'code': '101', 'value_represented': 'Sutter'},
#   {'code': '103', 'value_represented': 'Tehama'},
#   {'code': '105', 'value_represented': 'Trinity'},
#   {'code': '107', 'value_represented': 'Tulare'},
#   {'code': '109', 'value_represented': 'Tuolumne'},
#   {'code': '111', 'value_represented': 'Ventura'},
#   {'code': '113', 'value_represented': 'Yolo'},
#   {'code': '115', 'value_represented': 'Yuba'}]}

# %%
# Find Parameter Classes (groups of parameters, like criteria or all)
url_class = "https://aqs.epa.gov/data/api/list/classes?email={}&key={}".format(USER_ID, USER_KEY)

results = requests.get(url_class).json()
results["Data"]
# Out:
# [{'code': 'AIRNOW MAPS',
#   'value_represented': 'The parameters represented on AirNow maps (88101, 88502, and 44201)'},
#  {'code': 'ALL', 'value_represented': 'Select all Parameters Available'},
#  {'code': 'AQI POLLUTANTS',
#   'value_represented': 'Pollutants that have an AQI Defined'},
#  {'code': 'CORE_HAPS', 'value_represented': 'Urban Air Toxic Pollutants'},
#  {'code': 'CRITERIA', 'value_represented': 'Criteria Pollutants'},
#  {'code': 'CSN DART',
#   'value_represented': 'List of CSN speciation parameters to populate the STI DART tool'},
#  {'code': 'FORECAST',
#   'value_represented': 'Parameters routinely extracted by AirNow (STI)'},
#  {'code': 'HAPS', 'value_represented': 'Hazardous Air Pollutants'},
#  {'code': 'IMPROVE CARBON', 'value_represented': 'IMPROVE Carbon Parameters'},
#  {'code': 'IMPROVE_SPECIATION',
#   'value_represented': 'PM2.5 Speciated Parameters Measured at IMPROVE sites'},
#  {'code': 'MET', 'value_represented': 'Meteorological Parameters'},
#  {'code': 'NATTS CORE HAPS',
#   'value_represented': 'The core list of toxics of interest to the NATTS program.'},
#  {'code': 'NATTS REQUIRED',
#   'value_represented': 'Required compounds to be collected in the National Air Toxics Network'},
#  {'code': 'PAMS',
#   'value_represented': 'Photochemical Assessment Monitoring System'},
#  {'code': 'PAMS_VOC',
#   'value_represented': 'Volatile Organic Compound subset of the PAMS Parameters'},
#  {'code': 'PM COARSE',
#   'value_represented': 'PM between 2.5 and 10 micrometers'},
#  {'code': 'PM10 SPECIATION', 'value_represented': 'PM10 Speciated Parameters'},
#  {'code': 'PM2.5 CONT NONREF',
#   'value_represented': 'PM2.5 Continuous, Nonreference Methods'},
#  {'code': 'PM2.5 MASS/QA',
#   'value_represented': 'PM2.5 Mass and QA Parameters'},
#  {'code': 'SCHOOL AIR TOXICS',
#   'value_represented': 'School Air Toxics Program Parameters'},
#  {'code': 'SPECIATION', 'value_represented': 'PM2.5 Speciated Parameters'},
#  {'code': 'SPECIATION CARBON',
#   'value_represented': 'PM2.5 Speciation Carbon Parameters'},
#  {'code': 'SPECIATION CATION/ANION',
#   'value_represented': 'PM2.5 Speciation Cation/Anion Parameters'},
#  {'code': 'SPECIATION METALS',
#   'value_represented': 'PM2.5 Speciation Metal Parameters'},
#  {'code': 'UATMP CARBONYL',
#   'value_represented': 'Urban Air Toxics Monitoring Program Carbonyls'},
#  {'code': 'UATMP VOC',
#   'value_represented': 'Urban Air Toxics Monitoring Program VOCs'},
#  {'code': 'VOC', 'value_represented': 'Volatile organic compounds'}]

# %%
# Parameters in a class (obtain the list of classes from the List - Parameter Classes service)
url_param = "https://aqs.epa.gov/data/api/list/parametersByClass?email={}&key={}&pc=AQI%20POLLUTANTS".format(USER_ID, USER_KEY)

results = requests.get(url_param).json()
results["Data"]
# Out:
# [{'code': '42101', 'value_represented': 'Carbon monoxide'},
#  {'code': '42401', 'value_represented': 'Sulfur dioxide'},
#  {'code': '42602', 'value_represented': 'Nitrogen dioxide (NO2)'},
#  {'code': '44201', 'value_represented': 'Ozone'},
#  {'code': '81102', 'value_represented': 'PM10 Total 0-10um STP'},
#  {'code': '88101', 'value_represented': 'PM2.5 - Local Conditions'},
#  {'code': '88502',
#   'value_represented': 'Acceptable PM2.5 AQI & Speciation Mass'}]

# %%
# Find Sites by LA County
url_site = "https://aqs.epa.gov/data/api/list/sitesByCounty?email={}&key={}&state=06&county=037".format(USER_ID, USER_KEY)

results = requests.get(url_site).json()
results["Data"]

for i in range(len(results["Data"])): 
    if results["Data"][i]['value_represented'] != None:
        print(results["Data"][i])
# Out:
# {'code': '0002', 'value_represented': 'Azusa'}
# {'code': '0016', 'value_represented': 'Glendora'}
# {'code': '0018', 'value_represented': 'El Monte'}
# {'code': '0030', 'value_represented': 'SB25 trailer at Hollenbeck School'}
# {'code': '0031', 'value_represented': 'Wilmington-N. Mahar Ave'}
# {'code': '0113', 'value_represented': 'West Los Angeles'}
# {'code': '0201', 'value_represented': 'Carson'}
# {'code': '0202', 'value_represented': 'Commerce-Ayers Ave'}
# {'code': '0203', 'value_represented': 'City of Industry-Volkswagon'}
# {'code': '0204', 'value_represented': 'City of Industry-Whitco'}
# {'code': '0205', 'value_represented': 'Commerce-AT&SF RR'}
# {'code': '0206', 'value_represented': 'SITE IS LOCATED ONE HALF MILE EAST OF THE I-57/I-60 INTERCHANGE'}
# {'code': '1002', 'value_represented': 'Burbank'}
# {'code': '1101', 'value_represented': 'UNKNOWN COORDINATE LOCATION'}
# {'code': '1102', 'value_represented': 'ON BUILDING'}
# {'code': '1103', 'value_represented': 'Los Angeles-North Main Street'}
# {'code': '1105', 'value_represented': 'West Los Angeles-Robertson Blvd'}
# {'code': '1201', 'value_represented': 'Reseda'}
# {'code': '1301', 'value_represented': 'Lynwood'}
# {'code': '1302', 'value_represented': 'Compton'}
# {'code': '1402', 'value_represented': 'Van Nuys Airport'}
# {'code': '1403', 'value_represented': 'Uddelholm (Trojan Battery)'}
# {'code': '1404', 'value_represented': 'Closet World (Quemetco)'}
# {'code': '1405', 'value_represented': 'Rehrig (Exide)'}
# {'code': '1406', 'value_represented': 'ATSF (Exide)'}
# {'code': '1602', 'value_represented': 'Pico Rivera #2'}
# {'code': '1701', 'value_represented': 'Pomona'}
# {'code': '2005', 'value_represented': 'Pasadena'}
# {'code': '4002', 'value_represented': 'Long Beach (North)'}
# {'code': '4004', 'value_represented': 'Long Beach (South)'}
# {'code': '4006', 'value_represented': 'Long Beach (Hudson)'}
# {'code': '4008', 'value_represented': 'Long Beach-Route 710 Near Road'}
# {'code': '4009', 'value_represented': 'Signal Hill (LBSH)'}
# {'code': '4010', 'value_represented': 'North Hollywood (NOHO)'}
# {'code': '4101', 'value_represented': 'Santa Clarita-Honby St.'}
# {'code': '5001', 'value_represented': 'Hawthorne'}
# {'code': '5005', 'value_represented': 'LAX Hastings'}
# {'code': '5501', 'value_represented': 'Felton Elementary School'}
# {'code': '5502', 'value_represented': 'Santa Anita Christian Academy'}
# {'code': '5503', 'value_represented': 'Soto Street Elementary School'}
# {'code': '6012', 'value_represented': 'Santa Clarita'}
# {'code': '7001', 'value_represented': 'Lancaster-N. Beech St.'}
# {'code': '9000', 'value_represented': 'Wrightwood'}
# {'code': '9002', 'value_represented': 'Lancaster-Ponderosa St.'}
# {'code': '9003', 'value_represented': 'SAN DIMAS (US FORESTRY) EXPERIMENTAL FOREST'}
# {'code': '9004', 'value_represented': 'AIR RESOURCES BOARD BUILDING, EL MONTE'}
# {'code': '9005', 'value_represented': 'EL MONTE AIRPORT - PROFILER FOR SCOS97'}
# {'code': '9006', 'value_represented': 'Palmdale-East Ave S'}
# {'code': '9033', 'value_represented': 'Lancaster-Division Street'}
# {'code': '9034', 'value_represented': 'Lebec'}
# {'code': '9934', 'value_represented': 'San Gabriel Wilderness'}

# %%
# Find Sites in Ventura County
url_site = "https://aqs.epa.gov/data/api/list/sitesByCounty?email={}&key={}&state=06&county=111".format(USER_ID, USER_KEY)

results = requests.get(url_site).json()
results["Data"]

for i in range(len(results["Data"])): 
    if results["Data"][i]['value_represented'] != None:
        print(results["Data"][i])
# Out:
# {'code': '0007', 'value_represented': 'Thousand Oaks'}
# {'code': '0008', 'value_represented': 'SITE IN SIMI VALLEY LANDFILL. NEAREST TRAFFIC HWY 118, SO, 1/2 MI.'}
# {'code': '0009', 'value_represented': 'Piru - Pacific'}
# {'code': '1004', 'value_represented': 'Ojai - East Ojai Ave'}
# {'code': '2002', 'value_represented': 'Simi Valley-Cochran Street'}
# {'code': '2003', 'value_represented': 'Emma Wood State Beach, Ventura'}
# {'code': '3001', 'value_represented': 'El Rio-Rio Mesa School #2'}

# %% [markdown]
# Now we will pick the sensors which located in or near the LA NCs area and use the API to get their Ozone, PM2.5, and PM 10 data if any.

# %% [markdown]
# <h3>Compton Air Quality Data</h3>

# %%
site = "1302"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

Comp_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
len(Comp_df)
# Out:
# 3633

# %%
Comp_df['parameter'].unique()
# Out:
# array(['Ozone', 'PM2.5 - Local Conditions'], dtype=object)

# %% [markdown]
# <h3>LA Main Street Air Quality Data</h3>

# %%
# param = 44201,81102,88101,88502
site = 1103
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()
#results["Data"]

# %%
LA_df = pd.json_normalize(results["Data"])
LA_df.drop_duplicates()
LA_df['date_local'] = pd.to_datetime(LA_df['date_local'])
LA_df.sort_values(by=["date_local", "parameter"], inplace = True)
LA_df = LA_df.reset_index(drop=True)
LA_df.head(1)
# Out:
#   state_code county_code site_number parameter_code  poc  latitude  longitude  \
# 0         06         037        1103          44201    1  34.06659 -118.22688
#
#    datum parameter sample_duration_code sample_duration pollutant_standard  \
# 0  WGS84     Ozone                    1          1 HOUR  Ozone 1-hour 1979
#
#   date_local   units_of_measure event_type  observation_count  \
# 0 2020-01-01  Parts per million  No Events                 24
#
#    observation_percent validity_indicator  arithmetic_mean  first_max_value  \
# 0                100.0                  Y         0.015083            0.038
#
#    first_max_hour  aqi method_code                                  method  \
# 0              14  NaN         087  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
#
#                  local_site_name                 site_address       state  \
# 0  Los Angeles-North Main Street  1630 N MAIN ST, LOS ANGELES  California
#
#         county         city cbsa_code                                cbsa  \
# 0  Los Angeles  Los Angeles     31080  Los Angeles-Long Beach-Anaheim, CA
#
#   date_of_last_change
# 0          2021-10-31

# %%
LA_df.columns
# Out:
# Index(['state_code', 'county_code', 'site_number', 'parameter_code', 'poc',
#        'latitude', 'longitude', 'datum', 'parameter', 'sample_duration_code',
#        'sample_duration', 'pollutant_standard', 'date_local',
#        'units_of_measure', 'event_type', 'observation_count',
#        'observation_percent', 'validity_indicator', 'arithmetic_mean',
#        'first_max_value', 'first_max_hour', 'aqi', 'method_code', 'method',
#        'local_site_name', 'site_address', 'state', 'county', 'city',
#        'cbsa_code', 'cbsa', 'date_of_last_change'],
#       dtype='object')

# %%
LA_df = LA_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
LA_df.head(12)
# Out:
#    site_number parameter_code  latitude  longitude                 parameter  \
# 0         1103          44201  34.06659 -118.22688                     Ozone
# 1         1103          44201  34.06659 -118.22688                     Ozone
# 2         1103          44201  34.06659 -118.22688                     Ozone
# 3         1103          44201  34.06659 -118.22688                     Ozone
# 4         1103          88101  34.06659 -118.22688  PM2.5 - Local Conditions
# 5         1103          88101  34.06659 -118.22688  PM2.5 - Local Conditions
# 6         1103          88101  34.06659 -118.22688  PM2.5 - Local Conditions
# 7         1103          88101  34.06659 -118.22688  PM2.5 - Local Conditions
# 8         1103          88101  34.06659 -118.22688  PM2.5 - Local Conditions
# 9         1103          88101  34.06659 -118.22688  PM2.5 - Local Conditions
# 10        1103          44201  34.06659 -118.22688                     Ozone
# 11        1103          44201  34.06659 -118.22688                     Ozone
#
#    sample_duration_code          sample_duration pollutant_standard  \
# 0                     1                   1 HOUR  Ozone 1-hour 1979
# 1                     W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997
# 2                     W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 2008
# 3                     W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015
# 4                     7                  24 HOUR  PM25 24-hour 2006
# 5                     7                  24 HOUR   PM25 Annual 2006
# 6                     7                  24 HOUR  PM25 24-hour 2012
# 7                     7                  24 HOUR   PM25 Annual 2012
# 8                     7                  24 HOUR  PM25 24-hour 1997
# 9                     7                  24 HOUR   PM25 Annual 1997
# 10                    1                   1 HOUR  Ozone 1-hour 1979
# 11                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997
#
#    date_local             units_of_measure  observation_count  \
# 0  2020-01-01            Parts per million                 24
# 1  2020-01-01            Parts per million                 24
# 2  2020-01-01            Parts per million                 24
# 3  2020-01-01            Parts per million                 17
# 4  2020-01-01  Micrograms/cubic meter (LC)                  1
# 5  2020-01-01  Micrograms/cubic meter (LC)                  1
# 6  2020-01-01  Micrograms/cubic meter (LC)                  1
# 7  2020-01-01  Micrograms/cubic meter (LC)                  1
# 8  2020-01-01  Micrograms/cubic meter (LC)                  1
# 9  2020-01-01  Micrograms/cubic meter (LC)                  1
# 10 2020-01-02            Parts per million                 24
# 11 2020-01-02            Parts per million                 24
#
#     observation_percent  arithmetic_mean  first_max_value  first_max_hour  \
# 0                 100.0         0.015083            0.038              14
# 1                 100.0         0.014250            0.031              10
# 2                 100.0         0.014250            0.031              10
# 3                 100.0         0.016471            0.031              10
# 4                 100.0        17.400000           17.400               0
# 5                 100.0        17.400000           17.400               0
# 6                 100.0        17.400000           17.400               0
# 7                 100.0        17.400000           17.400               0
# 8                 100.0        17.400000           17.400               0
# 9                 100.0        17.400000           17.400               0
# 10                100.0         0.008875            0.033              11
# 11                100.0         0.008458            0.023               9
#
#      aqi                                             method  \
# 0    NaN             INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 1   29.0             INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 2   29.0             INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 3   29.0             INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 4   62.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 5   62.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 6   62.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 7   62.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 8   62.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 9   62.0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 10   NaN             INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 11  21.0             INSTRUMENTAL - ULTRA VIOLET ABSORPTION
#
#                    site_address
# 0   1630 N MAIN ST, LOS ANGELES
# 1   1630 N MAIN ST, LOS ANGELES
# 2   1630 N MAIN ST, LOS ANGELES
# 3   1630 N MAIN ST, LOS ANGELES
# 4   1630 N MAIN ST, LOS ANGELES
# 5   1630 N MAIN ST, LOS ANGELES
# 6   1630 N MAIN ST, LOS ANGELES
# 7   1630 N MAIN ST, LOS ANGELES
# 8   1630 N MAIN ST, LOS ANGELES
# 9   1630 N MAIN ST, LOS ANGELES
# 10  1630 N MAIN ST, LOS ANGELES
# 11  1630 N MAIN ST, LOS ANGELES

# %%
LA_df.tail(1)
# Out:
#      site_number parameter_code  latitude  longitude  \
# 4034        1103          88101  34.06659 -118.22688
#
#                      parameter sample_duration_code sample_duration  \
# 4034  PM2.5 - Local Conditions                    7         24 HOUR
#
#      pollutant_standard date_local             units_of_measure  \
# 4034   PM25 Annual 1997 2020-12-31  Micrograms/cubic meter (LC)
#
#       observation_count  observation_percent  arithmetic_mean  \
# 4034                  1                100.0              9.0
#
#       first_max_value  first_max_hour   aqi  \
# 4034              9.0               0  38.0
#
#                                                  method  \
# 4034  R & P Model 2025 PM-2.5 Sequential Air Sampler...
#
#                      site_address
# 4034  1630 N MAIN ST, LOS ANGELES

# %%
len(LA_df)
# Out:
# 4035

# %%
LA_df['parameter'].unique()
# Out:
# array(['Ozone', 'PM2.5 - Local Conditions', 'PM10 Total 0-10um STP'],
#       dtype=object)

# %%
sum(LA_df['parameter'] == "PM10 Total 0-10um STP")
# Out:
# 45

# %%
# Create a dataframe which contains PM10 only
LA10_df = LA_df.loc[(LA_df.parameter == "PM10 Total 0-10um STP")]
#LA10_df

# %%
# Find the number of days where we have multiple PM10 data
sum(LA10_df['date_local'].value_counts() > 1)
# Out:
# 0

# %%
# Create a PM10 df which only consist of date_loca, parameter, and aqi
LA10_final = LA10_df[['date_local', 'parameter','aqi']]

# %%
LA10_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 34 to 4002
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_local  45 non-null     datetime64[ns]
#  1   parameter   45 non-null     object
#  2   aqi         45 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 1.4+ KB

# %%
# Create a dataframe which contains Ozone only
LAO3_df = LA_df.loc[(LA_df.parameter == "Ozone") & (LA_df.pollutant_standard == 'Ozone 8-hour 2015')]
#LAO3_df

# %%
# Find the number of days where we have multiple Ozone data
sum(LAO3_df['date_local'].value_counts() > 1)
# Out:
# 0

# %%
# Find the date which Ozone data is missing
LAO3_in_df = LAO3_df.set_index('date_local')
print(pd.date_range(
  start="2020-01-01", end="2020-12-31").difference(LAO3_in_df.index))
# Out:
# DatetimeIndex(['2020-03-12', '2020-03-13', '2020-05-10', '2020-05-11',
#                '2020-05-16', '2020-05-17', '2020-05-18', '2020-05-20',
#                '2020-05-21', '2020-05-22', '2020-05-23', '2020-05-24',
#                '2020-05-25', '2020-05-26'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# Since the total number of days in 2020 is 366 and we only has 352 rows of Ozone data, this means that there are 14 days where the Ozone data does not exist. From above, we see that there are two missing values in March and 12 missing values in May.

# %%
# Create an Ozone df which only consist of date_local, parameter, and aqi
LAO3_final = LAO3_df[['date_local', 'parameter', 'aqi']]

# %%
LAO3_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 3 to 4028
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_local  352 non-null    datetime64[ns]
#  1   parameter   352 non-null    object
#  2   aqi         352 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 11.0+ KB

# %%
# Create a dataframe which contains PM25 only
LA25_df = LA_df.loc[(LA_df.parameter == "PM2.5 - Local Conditions") & (LA_df.pollutant_standard == 'PM25 24-hour 2012')]
#LA25_df

# %%
#LA25_df['date_local'].value_counts()

# %%
sum(LA25_df['date_local'].value_counts() > 1)
# Out:
# 65

# %%
# Find the date where the value counts of PM25 is double or more
#LA25_df[LA25_df['date_local'].map(LA25_df['date_local'].value_counts()) > 1].head(5)

# %%
#LA25_final = LA25_df[["site_number", "latitude", "longitude", "parameter", "date_local", "aqi", "site_address"]]
LA25_final = LA25_df[["date_local", "parameter", "aqi"]]
LA25_final = LA25_final.sort_values(['date_local', 'aqi'], ascending=[True, True])
LA25_final = LA25_final.drop_duplicates(subset='date_local', keep = "last")
#LA25_final

# %%
sum(LA25_final['date_local'].value_counts() > 1)
# Out:
# 0

# %%
LA25_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 363 entries, 6 to 4031
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_local  363 non-null    datetime64[ns]
#  1   parameter   363 non-null    object
#  2   aqi         363 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 11.3+ KB

# %%
# Find the date which PM25 data is missing
LA25_final_in_df = LA25_final.set_index('date_local')
print(pd.date_range(
  start="2020-01-01", end="2020-12-31").difference(LA25_final_in_df.index))
# Out:
# DatetimeIndex(['2020-01-09', '2020-02-07', '2020-09-25'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# <h4>Combine LA Main Street Ozone and PMs Air Quality Data</h4>

# %%
temp = pd.concat([LA25_final,LA10_final, LAO3_final])
temp = temp.sort_values(['date_local', 'parameter'], ascending=[True, True])
temp = temp.pivot(index = "date_local", columns = "parameter")
temp.columns=temp.columns.droplevel(0)
temp.reset_index(inplace=True)
temp.columns = ['date_local', 'Ozone', 'PM10 Total 0-10um STP', 'PM2.5 - Local Conditions']
temp['max_aqi'] = temp[["Ozone", 'PM10 Total 0-10um STP', 'PM2.5 - Local Conditions']].max(axis=1)
temp['latitude'], temp['longitude'], temp['site_address'] = [LA_df.latitude[0],LA_df.longitude[0], LA_df.site_address[0]]

# %%
LA_O3PM = temp.copy()
LA_O3PM.head()
# Out:
#   date_local  Ozone  PM10 Total 0-10um STP  PM2.5 - Local Conditions  max_aqi  \
# 0 2020-01-01   29.0                    NaN                      62.0     62.0
# 1 2020-01-02   21.0                    NaN                      62.0     62.0
# 2 2020-01-03   14.0                    NaN                      52.0     52.0
# 3 2020-01-04   20.0                   34.0                      69.0     69.0
# 4 2020-01-05   23.0                    NaN                      58.0     58.0
#
#    latitude  longitude                 site_address
# 0  34.06659 -118.22688  1630 N MAIN ST, LOS ANGELES
# 1  34.06659 -118.22688  1630 N MAIN ST, LOS ANGELES
# 2  34.06659 -118.22688  1630 N MAIN ST, LOS ANGELES
# 3  34.06659 -118.22688  1630 N MAIN ST, LOS ANGELES
# 4  34.06659 -118.22688  1630 N MAIN ST, LOS ANGELES

# %% [markdown]
# <h3>Long Beach (Hudson) Air Quality Data</h3>

# %%
site = "4006"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

LB_Hd_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
LB_Hd_df['date_local']
# Out:
# 0    2020-01-04
# 1    2020-01-10
# 2    2020-01-16
# 3    2020-01-22
# 4    2020-01-28
# 5    2020-02-03
# 6    2020-02-09
# 7    2020-02-15
# 8    2020-02-21
# 9    2020-02-27
# 10   2020-03-04
# 11   2020-03-10
# 12   2020-03-16
# 13   2020-03-22
# Name: date_local, dtype: datetime64[ns]

# %%
len(LB_Hd_df)
# Out:
# 14

# %%
LB_Hd_df['parameter'].unique()
# Out:
# array(['PM10 Total 0-10um STP'], dtype=object)

# %% [markdown]
# Long Beach (Hudson) only __has 14 rows of PM10 data (from early Januray 2020 to late March 2020)__ in 2020. Since the data is very small, we will not use the data from Long Beach (Hudson) monitoring station.

# %% [markdown]
# <h3>Long Beach - Route 710 Air Quality Data</h3>

# %%
site = "4008"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

LB_710_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
len(LB_710_df)
# Out:
# 4522

# %%
LB_710_df['parameter'].unique()
# Out:
# array(['PM2.5 - Local Conditions'], dtype=object)

# %% [markdown]
# <h3>Long Beach (South) Air Quality Data</h3>

# %%
site = "4004"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

LB_S_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
LB_S_df.head(1)
# Out:
#   site_number parameter_code  latitude  longitude                 parameter  \
# 0        4004          88101  33.79236 -118.17533  PM2.5 - Local Conditions
#
#   sample_duration_code sample_duration pollutant_standard date_local  \
# 0                    7         24 HOUR  PM25 24-hour 2006 2020-01-01
#
#               units_of_measure  observation_count  observation_percent  \
# 0  Micrograms/cubic meter (LC)                  1                100.0
#
#    arithmetic_mean  first_max_value  first_max_hour   aqi  \
# 0             26.1             26.1               0  80.0
#
#                                               method  \
# 0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
#
#                              site_address
# 0  1305 E. Pacific Coast Hwy., Long Beach

# %%
len(LB_S_df)
# Out:
# 4663

# %%
LB_S_df['parameter'].unique()
# Out:
# array(['PM2.5 - Local Conditions', 'PM10 Total 0-10um STP'], dtype=object)

# %% [markdown]
# <h3>Long Beach (Signal Hill) Air Quality Data</h3>

# %%
site = "4009"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

LB_Sg_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
LB_Sg_df.head(1)
# Out:
#   site_number parameter_code   latitude   longitude parameter  \
# 0        4009          44201  33.793713 -118.171019     Ozone
#
#   sample_duration_code sample_duration pollutant_standard date_local  \
# 0                    1          1 HOUR  Ozone 1-hour 1979 2020-01-01
#
#     units_of_measure  observation_count  observation_percent  arithmetic_mean  \
# 0  Parts per million                 24                100.0         0.019708
#
#    first_max_value  first_max_hour  aqi  \
# 0            0.041              14  NaN
#
#                                    method         site_address
# 0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  1710 E. 20th Street

# %%
len(LB_Sg_df)
# Out:
# 1400

# %%
LB_Sg_df['parameter'].unique()
# Out:
# array(['Ozone'], dtype=object)

# %% [markdown]
# Long Beach (South) and Long Beach (Signal Hill) are located in close proximity. Long Beach (South) has PM2.5 and PM10 data, while Long Beach (Signal Hill) has Ozone data. We will combine both data and called it __Long Beach (Signal Hill + South)__ and set the location of the combined dataset to the __location of Long Beach (Signal Hill)__.

# %% [markdown]
# <h4>Long Beach (Signal Hill + South) Air Quality Data</h4>

# %%
LB_Sg_S_df = pd.concat([LB_Sg_df, LB_S_df])
len(LB_Sg_S_df)
# Out:
# 6063

# %%
LB_Sg_S_df.head()
# Out:
#   site_number parameter_code   latitude   longitude parameter  \
# 0        4009          44201  33.793713 -118.171019     Ozone
# 1        4009          44201  33.793713 -118.171019     Ozone
# 2        4009          44201  33.793713 -118.171019     Ozone
# 3        4009          44201  33.793713 -118.171019     Ozone
# 4        4009          44201  33.793713 -118.171019     Ozone
#
#   sample_duration_code          sample_duration pollutant_standard date_local  \
# 0                    1                   1 HOUR  Ozone 1-hour 1979 2020-01-01
# 1                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997 2020-01-01
# 2                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 2008 2020-01-01
# 3                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015 2020-01-01
# 4                    1                   1 HOUR  Ozone 1-hour 1979 2020-01-02
#
#     units_of_measure  observation_count  observation_percent  arithmetic_mean  \
# 0  Parts per million                 24                100.0         0.019708
# 1  Parts per million                 24                100.0         0.021125
# 2  Parts per million                 24                100.0         0.021125
# 3  Parts per million                 17                100.0         0.026000
# 4  Parts per million                 22                 92.0         0.015045
#
#    first_max_value  first_max_hour   aqi  \
# 0            0.041              14   NaN
# 1            0.036              10  33.0
# 2            0.036              10  33.0
# 3            0.036              10  33.0
# 4            0.033              15   NaN
#
#                                    method         site_address
# 0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  1710 E. 20th Street
# 1  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  1710 E. 20th Street
# 2  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  1710 E. 20th Street
# 3  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  1710 E. 20th Street
# 4  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  1710 E. 20th Street

# %%
LB_Sg_S_df.tail()
# Out:
#      site_number parameter_code  latitude  longitude  \
# 4658        4004          88101  33.79236 -118.17533
# 4659        4004          88101  33.79236 -118.17533
# 4660        4004          88101  33.79236 -118.17533
# 4661        4004          88101  33.79236 -118.17533
# 4662        4004          88101  33.79236 -118.17533
#
#                      parameter sample_duration_code sample_duration  \
# 4658  PM2.5 - Local Conditions                    X   24-HR BLK AVG
# 4659  PM2.5 - Local Conditions                    X   24-HR BLK AVG
# 4660  PM2.5 - Local Conditions                    X   24-HR BLK AVG
# 4661  PM2.5 - Local Conditions                    X   24-HR BLK AVG
# 4662  PM2.5 - Local Conditions                    X   24-HR BLK AVG
#
#      pollutant_standard date_local             units_of_measure  \
# 4658   PM25 Annual 2006 2020-12-31  Micrograms/cubic meter (LC)
# 4659  PM25 24-hour 2012 2020-12-31  Micrograms/cubic meter (LC)
# 4660   PM25 Annual 2012 2020-12-31  Micrograms/cubic meter (LC)
# 4661  PM25 24-hour 1997 2020-12-31  Micrograms/cubic meter (LC)
# 4662   PM25 Annual 1997 2020-12-31  Micrograms/cubic meter (LC)
#
#       observation_count  observation_percent  arithmetic_mean  \
# 4658                  1                100.0             31.3
# 4659                  1                100.0             31.3
# 4660                  1                100.0             31.3
# 4661                  1                100.0             31.3
# 4662                  1                100.0             31.3
#
#       first_max_value  first_max_hour   aqi  \
# 4658             31.3               0  91.0
# 4659             31.3               0  91.0
# 4660             31.3               0  91.0
# 4661             31.3               0  91.0
# 4662             31.3               0  91.0
#
#                                                  method  \
# 4658  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4659  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4660  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4661  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4662  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#                                 site_address
# 4658  1305 E. Pacific Coast Hwy., Long Beach
# 4659  1305 E. Pacific Coast Hwy., Long Beach
# 4660  1305 E. Pacific Coast Hwy., Long Beach
# 4661  1305 E. Pacific Coast Hwy., Long Beach
# 4662  1305 E. Pacific Coast Hwy., Long Beach

# %% [markdown]
# <h3>Pico Rivera Air Quality Data</h3>

# %%
site = "1602"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

Pic_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
len(Pic_df)
# Out:
# 2544

# %%
Pic_df['parameter'].unique()
# Out:
# array(['Ozone', 'PM2.5 - Local Conditions'], dtype=object)

# %% [markdown]
# <h3>North Hollywood (NOHO) Air Quality Data</h3>

# %%
site = "4010"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
Noho_df = pd.json_normalize(results["Data"])
Noho_df.drop_duplicates()
Noho_df['date_local'] = pd.to_datetime(Noho_df['date_local'])
Noho_df.sort_values(by=["date_local", "parameter"], inplace = True)
Noho_df = Noho_df.reset_index(drop=True)

# %%
Noho_df = Noho_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
Noho_df.tail()
# Out:
#      site_number parameter_code   latitude   longitude parameter  \
# 1447        4010          44201  34.181977 -118.363036     Ozone
# 1448        4010          44201  34.181977 -118.363036     Ozone
# 1449        4010          44201  34.181977 -118.363036     Ozone
# 1450        4010          44201  34.181977 -118.363036     Ozone
# 1451        4010          44201  34.181977 -118.363036     Ozone
#
#      sample_duration_code          sample_duration pollutant_standard  \
# 1447                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015
# 1448                    1                   1 HOUR  Ozone 1-hour 1979
# 1449                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997
# 1450                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 2008
# 1451                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015
#
#      date_local   units_of_measure  observation_count  observation_percent  \
# 1447 2020-12-30  Parts per million                 17                100.0
# 1448 2020-12-31  Parts per million                 24                100.0
# 1449 2020-12-31  Parts per million                 19                 79.0
# 1450 2020-12-31  Parts per million                 19                 79.0
# 1451 2020-12-31  Parts per million                 12                 71.0
#
#       arithmetic_mean  first_max_value  first_max_hour   aqi  \
# 1447         0.013412            0.030              10  28.0
# 1448         0.021333            0.042              13   NaN
# 1449         0.024263            0.038              10  35.0
# 1450         0.024263            0.038              10  35.0
# 1451         0.033083            0.038              10  35.0
#
#                                       method            site_address
# 1447  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  10659 W. Delano Street
# 1448  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  10659 W. Delano Street
# 1449  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  10659 W. Delano Street
# 1450  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  10659 W. Delano Street
# 1451  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  10659 W. Delano Street

# %%
len(Noho_df)
# Out:
# 1452

# %%
Noho_df['parameter'].unique()
# Out:
# array(['Ozone'], dtype=object)

# %% [markdown]
# <h3>Pasadena Air Quality Data</h3>

# %%
site = "2005"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

Pas_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
len(Pas_df)
# Out:
# 2209

# %%
Pas_df['parameter'].unique()
# Out:
# array(['Ozone', 'PM2.5 - Local Conditions'], dtype=object)

# %% [markdown]
# <h3>Reseda Air Quality Data</h3>

# %%
site = "1201"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
Res_df = pd.json_normalize(results["Data"])
Res_df.drop_duplicates()
Res_df['date_local'] = pd.to_datetime(Res_df['date_local'])
Res_df.sort_values(by=["date_local", "parameter"], inplace = True)
Res_df = Res_df.reset_index(drop=True)

Res_df = Res_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
Res_df.head()
# Out:
#   site_number parameter_code  latitude  longitude                 parameter  \
# 0        1201          44201  34.19925 -118.53276                     Ozone
# 1        1201          44201  34.19925 -118.53276                     Ozone
# 2        1201          44201  34.19925 -118.53276                     Ozone
# 3        1201          44201  34.19925 -118.53276                     Ozone
# 4        1201          88101  34.19925 -118.53276  PM2.5 - Local Conditions
#
#   sample_duration_code          sample_duration pollutant_standard date_local  \
# 0                    1                   1 HOUR  Ozone 1-hour 1979 2020-01-01
# 1                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997 2020-01-01
# 2                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 2008 2020-01-01
# 3                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015 2020-01-01
# 4                    7                  24 HOUR  PM25 24-hour 2006 2020-01-01
#
#               units_of_measure  observation_count  observation_percent  \
# 0            Parts per million                 24                100.0
# 1            Parts per million                 24                100.0
# 2            Parts per million                 24                100.0
# 3            Parts per million                 17                100.0
# 4  Micrograms/cubic meter (LC)                  1                100.0
#
#    arithmetic_mean  first_max_value  first_max_hour   aqi  \
# 0         0.022375            0.047              14   NaN
# 1         0.026500            0.041              11  38.0
# 2         0.026500            0.041              11  38.0
# 3         0.032706            0.041              11  38.0
# 4        15.400000           15.400               0  58.0
#
#                                               method             site_address
# 0             INSTRUMENTAL - ULTRA VIOLET ABSORPTION  18330 GAULT ST., RESEDA
# 1             INSTRUMENTAL - ULTRA VIOLET ABSORPTION  18330 GAULT ST., RESEDA
# 2             INSTRUMENTAL - ULTRA VIOLET ABSORPTION  18330 GAULT ST., RESEDA
# 3             INSTRUMENTAL - ULTRA VIOLET ABSORPTION  18330 GAULT ST., RESEDA
# 4  R & P Model 2025 PM-2.5 Sequential Air Sampler...  18330 GAULT ST., RESEDA

# %%
Res_df.tail(1)
# Out:
#      site_number parameter_code  latitude  longitude parameter  \
# 2125        1201          44201  34.19925 -118.53276     Ozone
#
#      sample_duration_code          sample_duration pollutant_standard  \
# 2125                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015
#
#      date_local   units_of_measure  observation_count  observation_percent  \
# 2125 2020-12-31  Parts per million                 12                 71.0
#
#       arithmetic_mean  first_max_value  first_max_hour   aqi  \
# 2125            0.038             0.04               9  37.0
#
#                                       method             site_address
# 2125  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  18330 GAULT ST., RESEDA

# %%
len(Res_df)
# Out:
# 2126

# %%
Res_df['parameter'].unique()
# Out:
# array(['Ozone', 'PM2.5 - Local Conditions'], dtype=object)

# %% [markdown]
# <h3>Santa Clarita Air Quality Data</h3>

# %%
site = "6012"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

San_Cl_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
len(San_Cl_df)
# Out:
# 1483

# %%
San_Cl_df['parameter'].unique()
# Out:
# array(['Ozone', 'PM10 Total 0-10um STP'], dtype=object)

# %% [markdown]
# <h3>Simi Valley Air Quality Data</h3>

# %%
site = "2002"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=111&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
temp_df = pd.json_normalize(results["Data"])
temp_df.drop_duplicates()
temp_df['date_local'] = pd.to_datetime(temp_df['date_local'])
temp_df.sort_values(by=["date_local", "parameter"], inplace = True)
temp_df = temp_df.reset_index(drop=True)

Sim_V_df = temp_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
len(Sim_V_df)
# Out:
# 7230

# %%
Sim_V_df['parameter'].unique()
# Out:
# array(['Ozone', 'PM10 Total 0-10um STP', 'PM2.5 - Local Conditions'],
#       dtype=object)

# %% [markdown]
# <h3>West LA Air Quality Data</h3>

# %%
site = "0113"
url_data = "https://aqs.epa.gov/data/api/dailyData/bySite?email={}&key={}&param=44201,81102,88101&bdate={}&edate={}&state=06&county=037&site={}".format(USER_ID, USER_KEY, 20200101, 20201231, site)

results = requests.get(url_data).json()

# %%
West_LA_df = pd.json_normalize(results["Data"])
West_LA_df.drop_duplicates()
West_LA_df['date_local'] = pd.to_datetime(West_LA_df['date_local'])
West_LA_df.sort_values(by=["date_local", "parameter"], inplace = True)
West_LA_df = West_LA_df.reset_index(drop=True)

# %%
West_LA_df = West_LA_df.drop(['state_code', 'county_code', 'poc', 'datum', 'event_type', 'validity_indicator', 'method_code', 'local_site_name', 'state', 'county', 'cbsa_code', 'cbsa', 'date_of_last_change', 'city' ], axis=1)

# %%
West_LA_df.head(10)
# Out:
#   site_number parameter_code  latitude  longitude parameter  \
# 0        0113          44201  34.05111 -118.45636     Ozone
# 1        0113          44201  34.05111 -118.45636     Ozone
# 2        0113          44201  34.05111 -118.45636     Ozone
# 3        0113          44201  34.05111 -118.45636     Ozone
# 4        0113          44201  34.05111 -118.45636     Ozone
# 5        0113          44201  34.05111 -118.45636     Ozone
# 6        0113          44201  34.05111 -118.45636     Ozone
# 7        0113          44201  34.05111 -118.45636     Ozone
# 8        0113          44201  34.05111 -118.45636     Ozone
# 9        0113          44201  34.05111 -118.45636     Ozone
#
#   sample_duration_code          sample_duration pollutant_standard date_local  \
# 0                    1                   1 HOUR  Ozone 1-hour 1979 2020-01-01
# 1                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997 2020-01-01
# 2                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 2008 2020-01-01
# 3                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015 2020-01-01
# 4                    1                   1 HOUR  Ozone 1-hour 1979 2020-01-02
# 5                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997 2020-01-02
# 6                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 2008 2020-01-02
# 7                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-hour 2015 2020-01-02
# 8                    1                   1 HOUR  Ozone 1-hour 1979 2020-01-03
# 9                    W  8-HR RUN AVG BEGIN HOUR  Ozone 8-Hour 1997 2020-01-03
#
#     units_of_measure  observation_count  observation_percent  arithmetic_mean  \
# 0  Parts per million                 24                100.0         0.027167
# 1  Parts per million                 24                100.0         0.024500
# 2  Parts per million                 24                100.0         0.024500
# 3  Parts per million                 17                100.0         0.023941
# 4  Parts per million                 24                100.0         0.017333
# 5  Parts per million                 24                100.0         0.017417
# 6  Parts per million                 24                100.0         0.017417
# 7  Parts per million                 17                100.0         0.016706
# 8  Parts per million                 24                100.0         0.014708
# 9  Parts per million                 24                100.0         0.013208
#
#    first_max_value  first_max_hour   aqi  \
# 0            0.043              15   NaN
# 1            0.037               9  34.0
# 2            0.037               9  34.0
# 3            0.037               9  34.0
# 4            0.036              14   NaN
# 5            0.030               9  28.0
# 6            0.030               9  28.0
# 7            0.030               9  28.0
# 8            0.029              10   NaN
# 9            0.025              10  23.0
#
#                                    method                   site_address
# 0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 1  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 2  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 3  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 4  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 5  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 6  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 7  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 8  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES
# 9  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  VA HOSPITAL, WEST LOS ANGELES

# %%
len(West_LA_df)
# Out:
# 1456

# %%
West_LA_df['parameter'].unique()
# Out:
# array(['Ozone'], dtype=object)

# %%
# Create a dataframe which contains Ozone only
West_LAO3_df = West_LA_df.loc[(West_LA_df.pollutant_standard == 'Ozone 8-hour 2015')]
#West_LAO3_df

# %%
# Find the number of days where we have multiple Ozone data
sum(West_LAO3_df['date_local'].value_counts() > 1)
# Out:
# 0

# %%
# Find the date which Ozone data is missing
West_LAO3_in_df = West_LAO3_df.set_index('date_local')
print(pd.date_range(
  start="2020-01-01", end="2020-12-31").difference(West_LAO3_in_df.index))
# Out:
# DatetimeIndex(['2020-10-25', '2020-10-26'], dtype='datetime64[ns]', freq=None)

# %%
temp = West_LAO3_df[["date_local", "aqi", "latitude", 'longitude', 'site_address']]
temp['max_aqi'] = temp[['aqi']].copy()
temp = temp.rename(columns={'aqi': 'Ozone'})
temp = temp[['date_local', 'Ozone', 'max_aqi', 'latitude', 'longitude', 'site_address']]
# Out:
# C:\Users\susan\AppData\Local\Temp/ipykernel_17840/3103283612.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['max_aqi'] = temp[['aqi']].copy()

# %%
West_LA_O3 = temp.copy()
West_LA_O3.head()
# Out:
#    date_local  Ozone  max_aqi  latitude  longitude  \
# 3  2020-01-01   34.0     34.0  34.05111 -118.45636
# 7  2020-01-02   28.0     28.0  34.05111 -118.45636
# 11 2020-01-03   23.0     23.0  34.05111 -118.45636
# 15 2020-01-04   29.0     29.0  34.05111 -118.45636
# 19 2020-01-05   36.0     36.0  34.05111 -118.45636
#
#                      site_address
# 3   VA HOSPITAL, WEST LOS ANGELES
# 7   VA HOSPITAL, WEST LOS ANGELES
# 11  VA HOSPITAL, WEST LOS ANGELES
# 15  VA HOSPITAL, WEST LOS ANGELES
# 19  VA HOSPITAL, WEST LOS ANGELES

# %% [markdown]
# <h2>Displaying the Map of the Monitoring Stations in the LA NCs Area.</h2>
#
# The NC geojson file was taken from:
# * [Neighborhood Councils (Certified) | City of Los Angeles Hub](https://geohub.lacity.org/datasets/9c8639737e3a457a8c0f6a93f9c36974/explore?location=34.020333%2C-118.412044%2C10.97)

# %% [markdown]
# <h3>Reading and Creating the Map of Los Angeles Neighborhoods Council</h3>

# %%
#f_name = 'Neighborhood_Councils_(Certified)/Neighborhood_Councils_(Certified).shp'
#nc = gpd.read_file(f_name)
#nc.head()

# %%
#nc['NC_ID'].unique()

# %%
nc_geo = r'Neighborhood_Councils_(Certified).geojson' # geojson file

longitude = -118.2518
latitude = 34.0488

# %%
fig = Figure(width=1000, height=700)
nc_map = folium.Map(location=[latitude, longitude], zoom_start=11, min_zoom=8,max_zoom=12)
fig.add_child(nc_map)
folium.TileLayer('CartoDB positron',name="Light Map").add_to(nc_map)
#nc_map

# %%
folium.Choropleth(geo_data = nc_geo,
        name='Choropleth',
        key_on='features.properties.Name',
        #line_color='green', 
        #fill_color='YlGn',
        fill_opacity=0.1, line_opacity=0.3
        ).add_to(nc_map) 
#folium.LayerControl().add_to(nc_map)

# %%
nc_map.save('nc.html')
#nc_map

# %%
#color_scale = np.array(['#7AF17A','#FFFF7A','#FFBC7A','#FF7A7A','#CA7AA2', '#A27A8E'])
#sns.palplot(sns.color_palette(color_scale))

# %% [markdown]
# <h3>Creating a Map of Monitoring Stations</h3>

# %%
# Create a Monitoring Stations Dataframe
columns = ["site_number", "site_address", "latitude", "longitude"]
df_names = [Comp_df, LA_df, LB_710_df, LB_S_df, LB_Sg_df, Noho_df, Pas_df, Res_df, Sim_V_df, San_Cl_df, West_LA_df]
all_stations = []

for i in df_names:
    fields = [i.site_number[0], i.site_address[0], i.latitude[0], i.longitude[0]]
    all_stations.append(fields)

stations_loc_df = pd.DataFrame(all_stations, columns = columns)

# %%
stations_loc_df.to_csv('EPA_stations.csv',  index=False)
stations_loc_df
# Out:
#    site_number                                 site_address   latitude  \
# 0         1302                        700 North Bullis Road  33.901389
# 1         1103                  1630 N MAIN ST, LOS ANGELES  34.066590
# 2         4008                        5895 Long Beach Blvd.  33.859662
# 3         4004       1305 E. Pacific Coast Hwy., Long Beach  33.792360
# 4         4009                          1710 E. 20th Street  33.793713
# 5         4010                       10659 W. Delano Street  34.181977
# 6         2005                 752 S. WILSON AVE., PASADENA  34.132600
# 7         1201                      18330 GAULT ST., RESEDA  34.199250
# 8         2002  5400 COCHRAN STREET, SIMI VALLEY, CA  93063  34.276316
# 9         6012     22224 PLACERITA CANYON RD, SANTA CLARITA  34.383440
# 10        0113                VA HOSPITAL, WEST LOS ANGELES  34.051110
#
#      longitude
# 0  -118.205000
# 1  -118.226880
# 2  -118.200707
# 3  -118.175330
# 4  -118.171019
# 5  -118.363036
# 6  -118.127200
# 7  -118.532760
# 8  -118.683685
# 9  -118.528400
# 10 -118.456360

# %%
# Set the radius of the circles surrounding the monitoring stations in meter
miles = 2
meters_c = miles * 1609.34

# %%
# Plot the selected sensors
for i, lat, lng, site_address, site_number in zip(stations_loc_df.index.values.tolist(),stations_loc_df.latitude, stations_loc_df.longitude, stations_loc_df.site_address, stations_loc_df.site_number):
    tooltip_text = site_address+", ID: " + str(site_number)
    
    folium.CircleMarker([lat, lng], radius = 15, color = "green", weight=1,
                fill = True, fill_color = "green", fill_opacity = 0.1,
                tooltip=tooltip_text).add_to(nc_map)
    folium.Circle([lat, lng], radius = meters_c, color = "blue",  weight=1.5,
                             ).add_to(nc_map)
    folium.Marker([lat, lng],
    icon=folium.DivIcon(html=f"""<div style="font-family: Arial; 
    color: b; font-weight: bold; font size="+5"">{i}</div>""")
    ).add_to(nc_map)
nc_map.save('south_coast_stations.html')
nc_map
# Out:
# <iframe src="about:blank" width="1000" height="700"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e04cb32f25e143cebd814c68cfc27ae6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e04cb32f25e143cebd814c68cfc27ae6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e04cb32f25e143cebd814c68cfc27ae6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e04cb32f25e143cebd814c68cfc27ae6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.0488%2C%20-118.2518%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20% ...

# %% [markdown]
# Only four sensors which belong to South Coast Air Quality Management District are located in the LA NCs area. These four sensors won't give us enough information needed to find the relationship between air quality and the 311 requests.
